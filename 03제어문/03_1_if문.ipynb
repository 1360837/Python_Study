# %% [markdown]
# <a href="https://colab.research.google.com/github/1360837/Python_Study/blob/main/03%EC%A0%9C%EC%96%B4%EB%AC%B8/03_1_if%EB%AC%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # if문은 왜 필요할까?

# %%
money=True
if money:
  print("택시를 타고 가라")
else :
  print("걸어 가라")

# %% [markdown]
# # if문의 기본 구조
#
# ![img.png](data:image/png;base64,...)

# %% [markdown]
# 들여쓰기
#
#
# > if 조건문: 바로 아래 문장부터 if문에 속하는 모든 문장에 들여쓰기를 해주어야 한다.

# %% [markdown]
# 조건문 다음에 콜론(:)

# %% [markdown]
# # 조건문이란 무엇인가?
#
#
# > 참과 거짓을 판단하는 문장

# %% [markdown]
# 비교 연산자
#
# ![image.png](data:image/png;base64,...)

# %%
x=3
y=2
print(x>y)
print(x<y)
print(x==y)
print(x!=y)
# Out:
# True
# False
# False
# True

# %%
#만약 3000원 이상의 돈을 가지고 있으면 택시를 타고 그렇지 않으면 걸어 가라. 
money=4500 #가지고 있는 돈의 액수
if money>=3000:
  print("택시를 타고 가라")
else :
  print("걸어 가라")
# Out:
# 택시를 타고 가라

# %% [markdown]
# and, or, not
#
# ![image.png](data:image/png;base64,...)

# %%
#만약 3000원 이상 있거나 카드가 있다면 택시를 타고 그렇지 않으면 걸어 가라.
money = 2000 #가지고 있는 돈의 액수
card = True #카드 유무
if money >=3000 or card:
  print("택시를 타고 가라")
else:
  print("걸어 가라")
# Out:
# 택시를 타고 가라

# %% [markdown]
# x in s, x not in s
#
# ![image.png](data:image/png;base64,...)

# %%
print(1 in [1,2,3])
print(1 not in [1,2,3])
# Out:
# True
# False

# %%
print('a' in ('a','b','c'))
print('j' not in 'python')
# Out:
# True
# True

# %%
#만약 주머니에 돈이 있으면 택시를 타고, 없느면 걸어 가라.
pocket = ['paper','cellphone','money']
if 'money' in pocket:
  print("택시를 타고 가라")
else:
  print("걸어 가라")
# Out:
# 택시를 타고 가라

# %%
#주머니에 카드가 없다면 걸어가고, 있다면 버스를 타고 가라
if 'card' not in pocket:
  print("걸어 가라.")
else:
  print('버스 타고 가라.')
# Out:
# 걸어 가라.

# %% [markdown]
# # 다양한 조건을 판단하는 elif
#
# ![image.png](data:image/png;base64,...)

# %%
#주머니에 돈이 있으면 택시를 타고, 주머니에 돈은 없지만 카드가 있으면 택시를 타고, 돈도 없고 카드도 없으면 걸어 가라.
pocket = ['paper','cellphone']
card = True
if 'money' in pocket:
  print("택시를 타고 가라.")
else:
  if 'card' in pocket:
    print("택시를 타고 가라.")
  else:
    print("걸어 가라.")
# Out:
# 걸어 가라.

# %%
if 'money' in pocket:
  print("택시를 타고 가라.")
elif card:
  print("택시를 타고 가라.")
else:
  print("걸어 가라.")
# Out:
# 택시를 타고 가라.

# %% [markdown]
# # 조건부 표현식
#
# ![image.png](data:image/png;base64,...)

# %%
score = 61

if score >= 60:
  message="success"
else:
  message="failure"
print(message)

message = "success" if score >= 60 else "failure"
print(message)
# Out:
# success
# success
